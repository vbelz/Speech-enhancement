# %%
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras import backend 
import tensorflow as tf
print(tf.__version__)

#Unet network
def unet(pretrained_weights = None,input_size = (128,128,1)):
    size_filter_in = 16
    #kernel_init = 'glorot_uniform'
    kernel_init = 'he_normal'
    activation_layer = None 
    inputs = Input(input_size)
    conv1 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(inputs)
    conv1 = LeakyReLU()(conv1)
    conv1 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv1)
    conv1 = LeakyReLU()(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool1)
    conv2 = LeakyReLU()(conv2)
    conv2 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv2)
    conv2 = LeakyReLU()(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool2)
    conv3 = LeakyReLU()(conv3)
    conv3 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv3)
    conv3 = LeakyReLU()(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool3)
    conv4 = LeakyReLU()(conv4)
    conv4 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv4)
    conv4 = LeakyReLU()(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(size_filter_in*16, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(pool4)
    conv5 = LeakyReLU()(conv5)
    conv5 = Conv2D(size_filter_in*16, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv5)
    conv5 = LeakyReLU()(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(size_filter_in*8, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(drop5))
    up6 = LeakyReLU()(up6)
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge6)
    conv6 = LeakyReLU()(conv6)
    conv6 = Conv2D(size_filter_in*8, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv6)
    conv6 = LeakyReLU()(conv6)
    up7 = Conv2D(size_filter_in*4, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(conv6))
    up7 = LeakyReLU()(up7)
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge7)
    conv7 = LeakyReLU()(conv7)
    conv7 = Conv2D(size_filter_in*4, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv7)
    conv7 = LeakyReLU()(conv7)
    up8 = Conv2D(size_filter_in*2, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(conv7))
    up8 = LeakyReLU()(up8)
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge8)
    conv8 = LeakyReLU()(conv8)
    conv8 = Conv2D(size_filter_in*2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv8)
    conv8 = LeakyReLU()(conv8)
    
    up9 = Conv2D(size_filter_in, 2, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(UpSampling2D(size = (2,2))(conv8))
    up9 = LeakyReLU()(up9)
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(merge9)
    conv9 = LeakyReLU()(conv9)
    conv9 = Conv2D(size_filter_in, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv9)
    conv9 = LeakyReLU()(conv9)
    conv9 = Conv2D(2, 3, activation = activation_layer, padding = 'same', kernel_initializer = kernel_init)(conv9)
    conv9 = LeakyReLU()(conv9)
    conv10 = Conv2D(1, 1, activation = 'tanh')(conv9)

    model = Model(inputs,conv10)

    model.compile(optimizer = 'adam', loss = tf.keras.losses.Huber(), metrics = ['mae'])
    
    #model.summary()

    if(pretrained_weights):
    	model.load_weights(pretrained_weights)

    return model
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# 1.15.0

# %%
#Mount drive folder
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/app/'
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
from scipy import stats

X_in = np.load(root_path+'X_in_10n_p2.npy')
X_ou = np.load(root_path+'X_ou_10n_p2.npy')
X_ou = X_in - X_ou

# %%
#Check distribution
print(stats.describe(X_in.reshape(-1,1)))
print(stats.describe(X_ou.reshape(-1,1)))
# Out:
# DescribeResult(nobs=327680000, minmax=(array([-80.]), array([3.81469727e-06])), mean=array([-45.86173657]), variance=array([263.05217213]), skewness=array([-0.05973985]), kurtosis=array([-0.35510073]))
# DescribeResult(nobs=327680000, minmax=(array([-68.04521561]), array([80.])), mean=array([5.82209216]), variance=array([123.11323437]), skewness=array([1.78879388]), kurtosis=array([3.23878353]))

# %%
#to scale between -1 and 1
X_in = (X_in + 46)/50
X_ou = (X_ou -6 )/82

print(X_in.shape)
#Check new distribution
print(stats.describe(X_in.reshape(-1,1)))
print(stats.describe(X_ou.reshape(-1,1)))
# Out:
# (20000, 128, 128)
# DescribeResult(nobs=327680000, minmax=(array([-0.68]), array([0.92000008])), mean=array([0.00276527]), variance=array([0.10522087]), skewness=array([-0.05973985]), kurtosis=array([-0.35510073]))
# DescribeResult(nobs=327680000, minmax=(array([-0.90299043]), array([0.90243902])), mean=array([-0.00216961]), variance=array([0.01830952]), skewness=array([1.78879388]), kurtosis=array([3.23878353]))

# %%
print(X_in.shape,X_ou.shape)
# Out:
# (20000, 128, 128) (20000, 128, 128)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
#Reshape for training
X_in = X_in[:,:,:]
X_in = X_in.reshape(X_in.shape[0],X_in.shape[1],X_in.shape[2],1)
X_ou = X_ou[:,:,:]
X_ou = X_ou.reshape(X_ou.shape[0],X_ou.shape[1],X_ou.shape[2],1)

X_train, X_test, y_train, y_test = train_test_split(X_in, X_ou, test_size=0.10, random_state=42)

#If training from pre-trained weights
generator_nn=unet(pretrained_weights = root_path+'mod_unet_last_weights.h5')

#If training from scratch
#generator_nn=unet()
#Save best models to disk
checkpoint = ModelCheckpoint('/content/gdrive/My Drive/app/model-{epoch:03d}-{loss:03f}-{val_loss:03f}.h5', verbose=1, monitor='val_loss',save_best_only=True, mode='auto')

generator_nn.summary()
#Training
history = generator_nn.fit(X_train, y_train, epochs=9, batch_size=80, shuffle=True, callbacks=[checkpoint], verbose=1, validation_data=(X_test, y_test))
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 16) 160         input_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 16)   0           leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 64, 64, 32)   4640        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 32)   0           leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 64)   18496       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)   0           leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 128)  73856       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 128)  0           leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 128)    0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 8, 8, 256)    295168      max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 256)    590080      leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, 8, 8, 256)    0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 8, 8, 256)    0           leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 16, 16, 256)  0           dropout_3[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 16, 16, 128)  131200      up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 256)  0           dropout_2[0][0]
#                                                                  leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 16, 16, 128)  295040      concatenate_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 16, 16, 128)  147584      leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, 16, 16, 128)  0           conv2d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 32, 32, 128)  0           leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 64)   32832       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 128)  0           leaky_re_lu_28[0][0]
#                                                                  leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 64)   73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 64)   36928       leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, 32, 32, 64)   0           conv2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 64)   0           leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 64, 64, 32)   8224        up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 64)   0           leaky_re_lu_26[0][0]
#                                                                  leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 64, 64, 32)   18464       concatenate_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 64, 64, 32)   9248        leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, 64, 64, 32)   0           conv2d_42[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 32) 0           leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 128, 128, 16) 2064        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_43[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 32) 0           leaky_re_lu_24[0][0]
#                                                                  leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 128, 128, 16) 4624        concatenate_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 128, 128, 16) 2320        leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, 128, 128, 16) 0           conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 128, 128, 2)  290         leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, 128, 128, 2)  0           conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 128, 128, 1)  3           leaky_re_lu_45[0][0]
# ==================================================================================================
# Total params: 1,941,093
# Trainable params: 1,941,093
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 18000 samples, validate on 2000 samples
# Epoch 1/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0024 - mean_absolute_error: 0.0424
# Epoch 00001: val_loss improved from inf to 0.00289, saving model to /content/gdrive/My Drive/app/model-001-0.002381-0.002886.h5
# 18000/18000 [==============================] - 38s 2ms/sample - loss: 0.0024 - mean_absolute_error: 0.0424 - val_loss: 0.0029 - val_mean_absolute_error: 0.0462
# Epoch 2/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0023 - mean_absolute_error: 0.0416
# Epoch 00002: val_loss did not improve from 0.00289
# 18000/18000 [==============================] - 35s 2ms/sample - loss: 0.0023 - mean_absolute_error: 0.0416 - val_loss: 0.0031 - val_mean_absolute_error: 0.0470
# Epoch 3/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0411
# Epoch 00003: val_loss improved from 0.00289 to 0.00261, saving model to /content/gdrive/My Drive/app/model-003-0.002232-0.002613.h5
# 18000/18000 [==============================] - 36s 2ms/sample - loss: 0.0022 - mean_absolute_error: 0.0411 - val_loss: 0.0026 - val_mean_absolute_error: 0.0441
# Epoch 4/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0407
# Epoch 00004: val_loss did not improve from 0.00261
# 18000/18000 [==============================] - 35s 2ms/sample - loss: 0.0022 - mean_absolute_error: 0.0407 - val_loss: 0.0026 - val_mean_absolute_error: 0.0436
# Epoch 5/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0022 - mean_absolute_error: 0.0405
# Epoch 00005: val_loss improved from 0.00261 to 0.00255, saving model to /content/gdrive/My Drive/app/model-005-0.002165-0.002552.h5
# 18000/18000 [==============================] - 36s 2ms/sample - loss: 0.0022 - mean_absolute_error: 0.0405 - val_loss: 0.0026 - val_mean_absolute_error: 0.0432
# Epoch 6/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0402
# Epoch 00006: val_loss improved from 0.00255 to 0.00241, saving model to /content/gdrive/My Drive/app/model-006-0.002129-0.002406.h5
# 18000/18000 [==============================] - 36s 2ms/sample - loss: 0.0021 - mean_absolute_error: 0.0402 - val_loss: 0.0024 - val_mean_absolute_error: 0.0416
# Epoch 7/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0398
# Epoch 00007: val_loss did not improve from 0.00241
# 18000/18000 [==============================] - 35s 2ms/sample - loss: 0.0021 - mean_absolute_error: 0.0399 - val_loss: 0.0027 - val_mean_absolute_error: 0.0437
# Epoch 8/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0399
# Epoch 00008: val_loss did not improve from 0.00241
# 18000/18000 [==============================] - 35s 2ms/sample - loss: 0.0021 - mean_absolute_error: 0.0398 - val_loss: 0.0024 - val_mean_absolute_error: 0.0420
# Epoch 9/9
# 17920/18000 [============================>.] - ETA: 0s - loss: 0.0021 - mean_absolute_error: 0.0398
# Epoch 00009: val_loss did not improve from 0.00241
# 18000/18000 [==============================] - 35s 2ms/sample - loss: 0.0021 - mean_absolute_error: 0.0398 - val_loss: 0.0027 - val_mean_absolute_error: 0.0443

# %%
#Plot training and validation loss
from matplotlib import pyplot as plt
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.yscale('log')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
#Predict and QC the output
X_pred_test = generator_nn.predict(X_test)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
id = 350
plt.imshow(X_test[id,:,:,0])

# %%
plt.imshow(y_test[id,:,:,0])

# %%
plt.imshow(X_pred_test[id,:,:,0])

# %%
from google.colab import drive
drive.mount('/content/gdrive')
root_path = 'gdrive/My Drive/app/'

# %%
#Save last model to disk
model_json = generator_nn.to_json()
with open("/content/gdrive/My Drive/app/mod_unet_last_weights.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
generator_nn.save_weights("/content/gdrive/My Drive/app/mod_unet_last_weights.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
